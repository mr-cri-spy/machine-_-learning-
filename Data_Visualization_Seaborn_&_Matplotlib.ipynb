# %% [markdown]
# <a href="https://colab.research.google.com/github/mr-cri-spy/machine-_-learning-/blob/main/Data_Visualization_Seaborn_%26_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Histogram

# %%
np.random.seed(40)
samples = np.random.randint(1,100,50)
print(samples)
plt.hist(samples)
plt.show()
# Out:
# [71 92  8 38 57 51 66 13 72 20 32 75 56 84 60 92 74 97 50 54 74  9 53 31
#  80 15 93 59 75 23  4 92 72 56 84 29 14 38 83 51 80 68 31 61 45 47 88 44
#  36 99]

# %%
ax = sns.histplot(samples)
ax.bar_label(ax.containers[0])
plt.show()

# %%
np.random.seed(40)
x = np.random.randint(1,50,10)
y = ["A","B","C","D","E","F","G","H","I","J"]
print(x)
plt.bar(y,x)
plt.show()
# Out:
# [ 7 28  8 38  2 13  8 20 32 11]

# %%
plt.hist(x)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
### Pie Chart

# %%
gender = tips['sex'].value_counts()
gender
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
gender.values
# Out:
# array([157,  87])

# %%
gender.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category', name='sex')

# %%
plt.pie(gender.values,labels = gender.index,autopct="%0.2f%%")
plt.show()

# %%
days = tips['day'].value_counts()
days
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
plt.pie(days.values,labels = days.index,autopct="%0.2f%%",explode=[0,0,0,0.2])
plt.show()

# %%
sns.countplot(x=tips['sex'])
plt.show()

# %%
sns.countplot(x=tips['sex'],hue=tips['smoker'])
plt.show()

# %%
sns.countplot(x=tips['sex'],hue=tips['day'])
plt.show()

# %%
### Line Plot

# %%
x = [3,8,9,10,15]
y = [30,40,50,10,100]
plt.plot(x,y)
plt.show()

# %%
a = [3,8,9,10,15]
b = [30,40,50,10,100]
sns.lineplot(x=a,y=b)
plt.show()

# %%
x = [3,8,9,10,15]
y = [30,40,50,10,100]
plt.plot(x,y,linewidth=3,linestyle='dotted',color="red")
plt.show()

# %%
x = [3,8,9,10,15]
y = [30,40,50,10,100]
plt.plot(x,y,linewidth=3,linestyle='dashed')
plt.show()

# %%
### Scatter Plot

# %%
plt.scatter(tips['total_bill'],tips['tip'])
plt.show()

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
plt.show()

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=80)
plt.show()

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=100,marker="*",color="red")   ## o,*,<,>,^,d
plt.show()

# %%
a = [3,8,9,10,15]
b = [30,40,50,10,100]
plt.plot(a,b)
plt.scatter(a,b)
plt.show()

# %%
a = [3,8,9,10,15]
b = [30,40,50,10,100]
sns.pointplot(x=a,y=b)
plt.show()

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],s=90,hue=tips['sex'])
plt.show()

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],s=90,hue=tips['day'])
plt.show()

# %%
### Rel Plot

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],kind="line")
plt.show()

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],kind="scatter",s=150,hue=tips['day'])
plt.show()

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],kind="scatter",s=150,hue=tips['day'],col=tips['day'],col_wrap=4)
plt.show()

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],kind="scatter",s=150,hue=tips['day'],col=tips['day'],col_wrap=2)
plt.show()

# %%
### Heatmap
np.random.seed(10)
samples = np.random.randint(1,100,(10,10))
samples
# Out:
# array([[10, 16, 65, 29, 90, 94, 30,  9, 74,  1],
#        [41, 37, 17, 12, 55, 89, 63, 34, 73, 79],
#        [50, 52, 55, 78, 70, 14, 26, 14, 93, 87],
#        [31, 31, 90, 13, 66, 32, 58, 37, 28, 19],
#        [94, 78, 23, 24, 95, 12, 29, 75, 89, 10],
#        [16, 19, 81, 72, 89, 12, 18, 47,  8, 76],
#        [29, 34, 85, 97, 89, 45,  6,  5, 72, 89],
#        [89, 51, 55, 35, 16, 78, 89, 16,  7, 86],
#        [23, 12, 13, 93, 97, 63, 58, 80, 43, 58],
#        [98, 51, 46, 41, 90, 74, 38,  1, 19, 24]])

# %%
sns.heatmap(samples,annot=True,cmap="Reds")
plt.show()

# %%
sns.heatmap(samples,annot=True,cmap="Reds",vmin=50,vmax=100)
plt.show()

# %%
tit_data = sns.load_dataset("titanic")
tit_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
x = tit_data[["age","fare","pclass","sibsp","parch"]].corr()
x
# Out:
#              age      fare    pclass     sibsp     parch
# age     1.000000  0.096067 -0.369226 -0.308247 -0.189119
# fare    0.096067  1.000000 -0.549500  0.159651  0.216225
# pclass -0.369226 -0.549500  1.000000  0.083081  0.018443
# sibsp  -0.308247  0.159651  0.083081  1.000000  0.414838
# parch  -0.189119  0.216225  0.018443  0.414838  1.000000

# %%
sns.heatmap(data=x,annot=True,cmap="Reds")
plt.show()
